# %% [markdown]
# # 现金流与微盘：可执行研究笔记
# 从仓库根目录运行；使用共享数据，不复制原始行情。结果是指数点位对照，不是已验证策略收益。规则、局限与首轮结论见同目录 README.md 和 findings-20260909.md。

# %%
from pathlib import Path
from market_research.studies.index_study import run_study
output = run_study(Path('studies/index_replication/study.example.json'))
output

# %%
import pandas as pd
pd.read_csv(output / 'comparison.csv')

# %%
from IPython.display import HTML, display
display(HTML((output / 'report.html').read_text()))
